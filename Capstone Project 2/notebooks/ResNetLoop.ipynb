# %%
import sys
import os, os.path

sys.path.append(os.path.join(os.getcwd() ,'/modules'))
root_path = "C:/git/Springboard-Public/Capstone Project 2/"
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    root_path = "/content/drive/My Drive/Capstone Project 2/"

print('Current Working Dir: ', os.getcwd())
print('Root Path: ', root_path)

# We need to set the working directory since we are using relative paths from various locations
if os.getcwd() != root_path:
  os.chdir(root_path)
# Out:
# Current Working Dir:  C:\git\Springboard-Public\Capstone Project 2\notebooks
# Root Path:  C:/git/Springboard-Public/Capstone Project 2/

# %%
from modules.lib.StandardTraining import *
from modules.models.ResNet import ResNet_GrayScale_12_Out

from torchsummary import summary

# %matplotlib inline

# %%
force_cpu = True
device = torch.device('cuda' if ~force_cpu and torch.cuda.is_available() else 'cpu')
# Assume that we are on a CUDA machine, then this should print a CUDA device:
print(f'Working on device={device}')
# Out:
# Working on device=cuda

# %%
class Nets:
    
    def __init__(self):
        self.cur_idx = 0
        self.nets = []
        layers = [18, 34] # ResNet Laysers 18, 34, 50, 101, 152
        lrs = [1e-4, 1e-5]
        batch_sizes = [32, 64]

        combinations = [(l, lr, bs) for l in layers for lr in lrs for bs in batch_sizes] 

        for combination in combinations:
            layers, lr, batch_size = combination   
            name = 'ResNet' + str(layers) + f'    learning rate:{lr}  batch size:{batch_size}'
            self.nets.append((name, layers, lr, batch_size))
            
    def __iter__(self):
        for name, layers, lr, batch_size in self.nets:
            net = ResNet_GrayScale_12_Out(layers=layers)
            net = nn.DataParallel(net)
            net.to(device)
            yield (name, net, lr, batch_size)
    
    def __len__(self):
        return len(self.nets)

# %%
modelLoop = ModelLoop(number_images=2500, 
                      default_batch_size=32, 
                      default_learning_rate = 1e-4,
                      num_epochs=4,
                      device=device, 
                      nets=Nets())
# Out:
# C:\git\Springboard-Public\Capstone Project 2\modules\lib\ChextXRayImages.py:251: UserWarning:
# Feature Imbalance Detected (train % - val %):
#    Edema: 3.22%
#
#   self.warnFeatureImbalance(train, value)
# Number of Training Images: 2,013
# Number of Validation Images: 487

# %%
modelLoop.train()
# Out:
# ▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆
#
# ResNet18    learning rate:0.0001  batch size:32
#
# ▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [1/4]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# Epoch Loss: 11.6137
# Training Time: 0:00:16.559532
# Validation Time: 0:00:02.444432
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [2/4]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# Epoch Loss: 9.8591
# Training Time: 0:00:15.252235
# Validation Time: 0:00:02.440473
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [3/4]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# Epoch Loss: 9.3214
# Training Time: 0:00:15.213332
# Validation Time: 0:00:02.389586
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [4/4]
# ...
