# %%
import sys
import os, os.path

sys.path.append(os.path.join(os.getcwd() ,'/modules'))
root_path = "C:/git/Springboard-Public/Capstone Project 2/"
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    root_path = "/content/drive/My Drive/Capstone Project 2/"

print('Current Working Dir: ', os.getcwd())
print('Root Path: ', root_path)

# We need to set the working directory since we are using relative paths from various locations
if os.getcwd() != root_path:
  os.chdir(root_path)
# Out:
# Current Working Dir:  C:\git\Springboard-Public\Capstone Project 2\notebooks
# Root Path:  C:/git/Springboard-Public/Capstone Project 2/

# %%
from modules.lib.StandardTraining import *
from modules.models.ResNet import ResNet_GrayScale_12_Out

from torchsummary import summary

# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %matplotlib inline

# %%
force_cpu = True
device = torch.device('cuda' if ~force_cpu and torch.cuda.is_available() else 'cpu')
# Assume that we are on a CUDA machine, then this should print a CUDA device:
print(f'Working on device={device}')
# Out:
# Working on device=cuda

# %%
net = ResNet_GrayScale_12_Out(layers=18, drop_out_precent=0.2) #18, 34, 50, 101, 152

net = nn.DataParallel(net)
net.to(device)


summary(net, (1, 320, 320))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 160, 160]           3,136
#        BatchNorm2d-2         [-1, 64, 160, 160]             128
#               ReLU-3         [-1, 64, 160, 160]               0
#          MaxPool2d-4           [-1, 64, 80, 80]               0
#             Conv2d-5           [-1, 64, 80, 80]          36,864
#        BatchNorm2d-6           [-1, 64, 80, 80]             128
#               ReLU-7           [-1, 64, 80, 80]               0
#             Conv2d-8           [-1, 64, 80, 80]          36,864
#        BatchNorm2d-9           [-1, 64, 80, 80]             128
#              ReLU-10           [-1, 64, 80, 80]               0
#        BasicBlock-11           [-1, 64, 80, 80]               0
#            Conv2d-12           [-1, 64, 80, 80]          36,864
#       BatchNorm2d-13           [-1, 64, 80, 80]             128
#              ReLU-14           [-1, 64, 80, 80]               0
#            Conv2d-15           [-1, 64, 80, 80]          36,864
#       BatchNorm2d-16           [-1, 64, 80, 80]             128
#              ReLU-17           [-1, 64, 80, 80]               0
#        BasicBlock-18           [-1, 64, 80, 80]               0
#            Conv2d-19          [-1, 128, 40, 40]          73,728
#       BatchNorm2d-20          [-1, 128, 40, 40]             256
#              ReLU-21          [-1, 128, 40, 40]               0
#            Conv2d-22          [-1, 128, 40, 40]         147,456
#       BatchNorm2d-23          [-1, 128, 40, 40]             256
#            Conv2d-24          [-1, 128, 40, 40]           8,192
#       BatchNorm2d-25          [-1, 128, 40, 40]             256
#              ReLU-26          [-1, 128, 40, 40]               0
#        BasicBlock-27          [-1, 128, 40, 40]               0
#            Conv2d-28          [-1, 128, 40, 40]         147,456
#       BatchNorm2d-29          [-1, 128, 40, 40]             256
#              ReLU-30          [-1, 128, 40, 40]               0
#            Conv2d-31          [-1, 128, 40, 40]         147,456
#       BatchNorm2d-32          [-1, 128, 40, 40]             256
#              ReLU-33          [-1, 128, 40, 40]               0
#        BasicBlock-34          [-1, 128, 40, 40]               0
#            Conv2d-35          [-1, 256, 20, 20]         294,912
#       BatchNorm2d-36          [-1, 256, 20, 20]             512
#              ReLU-37          [-1, 256, 20, 20]               0
#            Conv2d-38          [-1, 256, 20, 20]         589,824
#       BatchNorm2d-39          [-1, 256, 20, 20]             512
#            Conv2d-40          [-1, 256, 20, 20]          32,768
#       BatchNorm2d-41          [-1, 256, 20, 20]             512
#              ReLU-42          [-1, 256, 20, 20]               0
#        BasicBlock-43          [-1, 256, 20, 20]               0
#            Conv2d-44          [-1, 256, 20, 20]         589,824
#       BatchNorm2d-45          [-1, 256, 20, 20]             512
#              ReLU-46          [-1, 256, 20, 20]               0
#            Conv2d-47          [-1, 256, 20, 20]         589,824
#       BatchNorm2d-48          [-1, 256, 20, 20]             512
#              ReLU-49          [-1, 256, 20, 20]               0
#        BasicBlock-50          [-1, 256, 20, 20]               0
#            Conv2d-51          [-1, 512, 10, 10]       1,179,648
#       BatchNorm2d-52          [-1, 512, 10, 10]           1,024
#              ReLU-53          [-1, 512, 10, 10]               0
#            Conv2d-54          [-1, 512, 10, 10]       2,359,296
#       BatchNorm2d-55          [-1, 512, 10, 10]           1,024
#            Conv2d-56          [-1, 512, 10, 10]         131,072
#       BatchNorm2d-57          [-1, 512, 10, 10]           1,024
#              ReLU-58          [-1, 512, 10, 10]               0
#        BasicBlock-59          [-1, 512, 10, 10]               0
#            Conv2d-60          [-1, 512, 10, 10]       2,359,296
#       BatchNorm2d-61          [-1, 512, 10, 10]           1,024
#              ReLU-62          [-1, 512, 10, 10]               0
#            Conv2d-63          [-1, 512, 10, 10]       2,359,296
#       BatchNorm2d-64          [-1, 512, 10, 10]           1,024
#              ReLU-65          [-1, 512, 10, 10]               0
#        BasicBlock-66          [-1, 512, 10, 10]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                 [-1, 1000]         513,000
#            ResNet-69                 [-1, 1000]               0
#            Linear-70                   [-1, 12]          12,012
# ResNet_GrayScale_12_Out-71                   [-1, 12]               0
# ================================================================
# Total params: 11,695,252
# Trainable params: 11,695,252
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.39
# Forward/backward pass size (MB): 128.14
# Params size (MB): 44.61
# Estimated Total Size (MB): 173.15
# ----------------------------------------------------------------

# %%
standardTraining = StandardTraining(number_images=0, 
                                     batch_size=32, 
                                     learning_rate=1e-4, 
                                     num_epochs=20,
                                     device=device, 
                                     net=net,
                                     use_positivity_weights=True,
                                     observation_min_count = 40)
# Out:
# Total Oversampled Rows Added to Train: 21,678
#
# Number of Training Images: 127,055
# Number of Validation Images: 26,371
#
# \Positive Weights used in BCEWithLogitsLoss:
# Enlarged_Cardiomediastinum     9.730997
# Cardiomegaly                   5.511300
# Lung_Opacity                   1.136024
# Lung_Lesion                   10.819070
# Edema                          3.019965
# Consolidation                  8.706264
# Pneumonia                     15.786233
# Atelectasis                    4.322790
# Pneumothorax                   8.037914
# Pleural_Effusion               1.767299
# Pleural_Other                 21.946541
# Fracture                      11.299613
# dtype: float64

# %%
standardTraining.train()
# Out:
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [1/20]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# Epoch Loss: 1365.3632
# Time of Completion: 2020-07-24 11:22:03.169789
# Training Time: 0:18:20.565811
# Validation Time: 0:02:17.500546
#
# TRAINING
#
# ▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                19513  0.052017   0.134455  0.075013
# 4             Edema                31606  0.127666   0.245110  0.167887
# 5     Consolidation                13090  0.006035   0.062107  0.011001
# 7       Atelectasis                23870  0.006452   0.151874  0.012377
# 9  Pleural_Effusion                45913  0.299893   0.359588  0.327039
#
#     ROC AUC  Avg Precision
# 1  0.487742       0.147535
# 4  0.497272       0.246666
# 5  0.478383       0.096065
# 7  0.502361       0.187553
# 9  0.496289       0.359670
# VALIDATION
#
# ▔▔▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                 2976  0.474798   0.428441  0.450430
# 4             Edema                 6180  0.102913   0.701213  0.179484
# 5     Consolidation                 1584  0.000000   0.000000  0.000000
# 7       Atelectasis                 4088  0.002691   0.250000  0.005324
# 9  Pleural_Effusion                 8968  0.503568   0.747930  0.601893
#
#     ROC AUC  Avg Precision
# 1  0.823287       0.428648
# 4  0.800562       0.528038
# 5  0.676977       0.105672
# 7  0.619067       0.212994
# 9  0.836072       0.721796
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [2/20]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# Epoch Loss: 1147.5230
# Time of Completion: 2020-07-24 11:42:46.914296
# Training Time: 0:18:23.830288
# Validation Time: 0:02:18.841109
#
# TRAINING
#
# ▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                19513  0.081484   0.135043  0.101640
# 4             Edema                31606  0.156806   0.237243  0.188814
# 5     Consolidation                13090  0.022307   0.063547  0.033022
# 7       Atelectasis                23870  0.035735   0.154809  0.058067
# 9  Pleural_Effusion                45913  0.320149   0.356469  0.337334
#
#     ROC AUC  Avg Precision
# 1  0.490949       0.147647
# 4  0.497977       0.244052
# 5  0.482144       0.095970
# 7  0.504446       0.185885
# 9  0.495672       0.356599
# VALIDATION
#
# ▔▔▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                 2976  0.129368   0.740385  0.220252
# 4             Edema                 6180  0.124110   0.708872  0.211237
# 5     Consolidation                 1584  0.012626   0.142857  0.023202
# 7       Atelectasis                 4088  0.001957   0.380952  0.003894
# 9  Pleural_Effusion                 8968  0.506133   0.759284  0.607387
#
#     ROC AUC  Avg Precision
# 1  0.835535       0.458551
# 4  0.808184       0.541607
# 5  0.678344       0.111849
# 7  0.633829       0.220119
# 9  0.845533       0.734541
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [3/20]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# Epoch Loss: 1048.6398
# Time of Completion: 2020-07-24 12:03:54.626646
# Training Time: 0:18:48.375654
# Validation Time: 0:02:18.239627
#
# TRAINING
#
# ▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                19513  0.086096   0.130831  0.103851
# 4             Edema                31606  0.169904   0.239433  0.198764
# 5     Consolidation                13090  0.026891   0.062389  0.037583
# 7       Atelectasis                23870  0.048638   0.159128  0.074504
# 9  Pleural_Effusion                45913  0.326117   0.356144  0.340470
#
#     ROC AUC  Avg Precision
# 1  0.493890       0.147731
# 4  0.500103       0.243809
# 5  0.486498       0.096351
# 7  0.508490       0.186708
# 9  0.495633       0.355768
# VALIDATION
#
# ▔▔▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                 2976  0.255376   0.608974  0.359848
# 4             Edema                 6180  0.411489   0.570947  0.478277
# 5     Consolidation                 1584  0.049874   0.150190  0.074882
# 7       Atelectasis                 4088  0.113014   0.265976  0.158627
# 9  Pleural_Effusion                 8968  0.670941   0.683362  0.677094
#
#     ROC AUC  Avg Precision
# 1  0.833642       0.453053
# 4  0.808883       0.539960
# 5  0.667311       0.103045
# 7  0.626225       0.219028
# 9  0.845788       0.737604
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [4/20]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# Epoch Loss: 981.9707
# Time of Completion: 2020-07-24 12:24:32.885255
# Training Time: 0:18:18.675182
# Validation Time: 0:02:18.419559
#
# TRAINING
#
# ▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                19513  0.091682   0.132460  0.108362
# 4             Edema                31606  0.175726   0.237269  0.201912
# 5     Consolidation                13090  0.030863   0.063027  0.041436
# 7       Atelectasis                23870  0.057813   0.159833  0.084913
# 9  Pleural_Effusion                45913  0.331475   0.358448  0.344434
#
#     ROC AUC  Avg Precision
# 1  0.492754       0.147574
# 4  0.498384       0.243021
# 5  0.489923       0.096676
# 7  0.507205       0.185422
# 9  0.497691       0.356253
# VALIDATION
#
# ▔▔▔▔▔▔▔
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                 2976  0.071909   0.778182  0.131652
# 4             Edema                 6180  0.308091   0.608112  0.408979
# 5     Consolidation                 1584  0.001263   0.111111  0.002497
# 7       Atelectasis                 4088  0.066047   0.274390  0.106467
# 9  Pleural_Effusion                 8968  0.462645   0.777112  0.579996
#
#     ROC AUC  Avg Precision
# 1  0.832749       0.455367
# 4  0.804725       0.538430
# 5  0.670774       0.104180
# 7  0.637195       0.223928
# 9  0.847475       0.734674
# ▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# Epoch [5/20]
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# ▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔
# 19.3% training progress

# %%
standardTraining.displayMetrics()
