# %%
import sys
import os, os.path

sys.path.append(os.path.join(os.getcwd() ,'/modules'))
root_path = "C:/git/Springboard-Public/Capstone Project 2/"
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    root_path = "/content/drive/My Drive/Capstone Project 2/"

print('Current Working Dir: ', os.getcwd())
print('Root Path: ', root_path)

# We need to set the working directory since we are using relative paths from various locations
if os.getcwd() != root_path:
  os.chdir(root_path)
# Out:
# Current Working Dir:  C:\git\Springboard-Public\Capstone Project 2\notebooks\Support Notebooks for Modules
# Root Path:  C:/git/Springboard-Public/Capstone Project 2/

# %%
from modules.lib.StandardTraining import *
from modules.models.ResNet import ResNet_GrayScale_12_Out

from torchsummary import summary

# %matplotlib inline

# %%
force_cpu = True
device = torch.device('cuda' if ~force_cpu and torch.cuda.is_available() else 'cpu')
# Assume that we are on a CUDA machine, then this should print a CUDA device:
print(f'Working on device={device}')
# Out:
# Working on device=cuda

# %%
nets = []

for layers in [18, 34, 50, 101, 152]:
    net = ResNet_GrayScale_12_Out(layers=layers)
    net = nn.DataParallel(net)
    net.to(device)
    name = 'ResNet' + str(layers)
    nets.append((name, net, 1e-3))

# %%
modelLoop = ModelLoop(number_images=500, 
                                     batch_size=1, 
                                     default_learning_rate = 1e-3,
                                     num_epochs=4,
                                     device=device, 
                                     nets=nets)
# Out:
# C:\git\Springboard-Public\Capstone Project 2\modules\lib\ChextXRayImages.py:251: UserWarning:
# Feature Imbalance Detected (train % - val %):
#    Cardiomegaly: 4.42%
#    Edema: 10.93%
#    Pneumonia: 2.42%
#    Fracture: 4.35%
#
#   self.warnFeatureImbalance(train, value)
# Number of Training Images: 414
# Number of Validation Images: 86

# %%
modelLoop.train()
# Out:
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ResNet18
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ==================================================
# Epoch [1/4]
# ==================================================
# Epoch Loss: 156.1429
# Training Time: 0:00:18.671069)
# Validation Time: 0:00:00.868678)
# ==================================================
# Epoch [2/4]
# ==================================================
# Epoch Loss: 144.5622
# Training Time: 0:00:17.431402)
# Validation Time: 0:00:00.908571)
# ==================================================
# Epoch [3/4]
# ==================================================
# Epoch Loss: 141.6639
# Training Time: 0:00:17.547093)
# Validation Time: 0:00:00.917548)
# ==================================================
# Epoch [4/4]
# ==================================================
# Epoch Loss: 140.3554
# Training Time: 0:00:17.415445)
# Validation Time: 0:00:00.872667)
#
# TRAINING
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#              Target  True Positive Count    Recall  Precision        F1  \
# 1      Cardiomegaly                   52  0.000000       0.00  0.000000
# 4             Edema                  103  0.000000       0.00  0.000000
# 5     Consolidation                   19  0.000000       0.00  0.000000
# 7       Atelectasis                   60  0.000000       0.00  0.000000
# 9  Pleural_Effusion                  139  0.064748       0.36  0.109756
#
#     ROC AUC  Avg Precision
# 1  0.546005       0.161110
# 4  0.548247       0.283230
# 5  0.502332       0.045090
# 7  0.553766       0.187113
# 9  0.514951       0.354575
# VALIDATION
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
#              Target  True Positive Count  Recall  Precision   F1  ROC AUC  \
# 1      Cardiomegaly                    7     0.0        0.0  0.0      NaN
# 4             Edema                   12     0.0        0.0  0.0      NaN
# 5     Consolidation                    4     0.0        0.0  0.0      NaN
# 7       Atelectasis                   17     0.0        0.0  0.0      NaN
# 9  Pleural_Effusion                   28     0.0        0.0  0.0      NaN
#
#    Avg Precision
# 1       0.117008
# 4       0.191674
# 5       0.122514
# 7       0.303733
# 9       0.287760
# {'ROC AUC': ValueError('Only one class present in y_true. ROC AUC score is not defined in that case.')}
#
#
#
#
#
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ResNet34
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ==================================================
# Epoch [1/4]
# ==================================================
# Epoch Loss: 155.0744
# Training Time: 0:00:28.552673)
# Validation Time: 0:00:01.285564)
# ==================================================
# Epoch [2/4]
# ==================================================
# Epoch Loss: 146.8450
# Training Time: 0:00:28.874058)
# Validation Time: 0:00:01.271107)
# ==================================================
# Epoch [3/4]
# ==================================================
# Epoch Loss: 141.6721
# Training Time: 0:00:29.131393)
# Validation Time: 0:00:01.244672)
# ==================================================
# Epoch [4/4]
# ==================================================
# Epoch Loss: 140.5885
# Training Time: 0:00:29.248999)
# Validation Time: 0:00:01.245691)
#
# TRAINING
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#              Target  True Positive Count  Recall  Precision   F1   ROC AUC  \
# 1      Cardiomegaly                   52     0.0        0.0  0.0  0.485338
# 4             Edema                  103     0.0        0.0  0.0  0.446259
# 5     Consolidation                   19     0.0        0.0  0.0  0.515390
# 7       Atelectasis                   60     0.0        0.0  0.0  0.459605
# 9  Pleural_Effusion                  139     0.0        0.0  0.0  0.471498
#
#    Avg Precision
# 1       0.125397
# 4       0.220855
# 5       0.052325
# 7       0.145903
# 9       0.321910
# VALIDATION
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
#              Target  True Positive Count  Recall  Precision   F1  ROC AUC  \
# 1      Cardiomegaly                    7     0.0        0.0  0.0      NaN
# 4             Edema                   12     0.0        0.0  0.0      NaN
# 5     Consolidation                    4     0.0        0.0  0.0      NaN
# 7       Atelectasis                   17     0.0        0.0  0.0      NaN
# 9  Pleural_Effusion                   28     0.0        0.0  0.0      NaN
#
#    Avg Precision
# 1       0.129365
# 4       0.145980
# 5       0.084762
# 7       0.378823
# 9       0.313132
# {'ROC AUC': ValueError('Only one class present in y_true. ROC AUC score is not defined in that case.')}
#
#
#
#
#
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ResNet50
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ==================================================
# Epoch [1/4]
# ==================================================
# Epoch Loss: 174.8625
# Training Time: 0:00:41.105370)
# Validation Time: 0:00:01.527915)
# ==================================================
# Epoch [2/4]
# ==================================================
# Epoch Loss: 147.9397
# Training Time: 0:00:39.588173)
# Validation Time: 0:00:01.556839)
# ==================================================
# Epoch [3/4]
# ==================================================
# Epoch Loss: 145.5935
# Training Time: 0:00:39.566232)
# Validation Time: 0:00:01.498993)
# ==================================================
# Epoch [4/4]
# ==================================================
# Epoch Loss: 144.1445
# Training Time: 0:00:39.701869)
# Validation Time: 0:00:01.527915)
#
# TRAINING
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#              Target  True Positive Count    Recall  Precision    F1   ROC AUC  \
# 1      Cardiomegaly                   52  0.000000   0.000000  0.00  0.485710
# 4             Edema                  103  0.000000   0.000000  0.00  0.463428
# 5     Consolidation                   19  0.000000   0.000000  0.00  0.505796
# 7       Atelectasis                   60  0.000000   0.000000  0.00  0.491384
# 9  Pleural_Effusion                  139  0.028777   0.190476  0.05  0.462472
#
#    Avg Precision
# 1       0.125099
# 4       0.229501
# 5       0.080212
# 7       0.137538
# 9       0.307373
# VALIDATION
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# C:\Users\youci\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:677: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
#              Target  True Positive Count  Recall  Precision   F1  ROC AUC  \
# 1      Cardiomegaly                    7     0.0        0.0  0.0      NaN
# 4             Edema                   12     0.0        0.0  0.0      NaN
# 5     Consolidation                    4     0.0        0.0  0.0      NaN
# 7       Atelectasis                   17     0.0        0.0  0.0      NaN
# 9  Pleural_Effusion                   28     0.0        0.0  0.0      NaN
#
#    Avg Precision
# 1       0.188079
# 4       0.164129
# 5       0.116593
# 7       0.172732
# 9       0.359243
# {'ROC AUC': ValueError('Only one class present in y_true. ROC AUC score is not defined in that case.')}
#
#
#
#
#
#
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ResNet101
# ████████████████████████████████████████████████████████████████████████████████████████████████████
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-0ce492920d76> in <module>
# ----> 1 modelLoop.train()
#
# C:\git\Springboard-Public\Capstone Project 2\modules\lib\StandardTraining.py in train(self)
#     138             name, metrics, trainingLoop = trainer
#     139             print(u"\u2588" * 100 + '\n' + name + '\n' + u"\u2588" * 100)
# --> 140             trainingLoop.train(self.num_epochs, self.train_loader, self.val_loader)
#     141             metrics.displayMetrics(*self.epoch_metric_display_args)
#     142             print('\n' * 5)
#
# C:\git\Springboard-Public\Capstone Project 2\modules\lib\TrainingLoop.py in train(self, num_epochs, train_loader, val_loader)
#      83                 ids, inputs, labels, outputs = self.processBatch(data)
#      84                 self.metrics.appendEpochBatchData(ids, outputs)
# ---> 85                 self.epoch_loss += self.backProp(outputs, labels)
#      86
#      87             self.metrics.closeEpoch(epoch)
#
# C:\git\Springboard-Public\Capstone Project 2\modules\lib\TrainingLoop.py in backProp(self, outputs, labels)
#      64         loss = self.criterion(outputs, labels)
#      65         loss.backward()
# ---> 66         self.optimizer.step()
#      67         return loss.item()
#      68
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\optim\adam.py in step(self, closure)
#      75                     state['exp_avg'] = torch.zeros_like(p.data, memory_format=torch.preserve_format)
#      76                     # Exponential moving average of squared gradient values
# ---> 77                     state['exp_avg_sq'] = torch.zeros_like(p.data, memory_format=torch.preserve_format)
#      78                     if amsgrad:
#      79                         # Maintains max of all exp. moving avg. of sq. grad. values
#
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 8.00 GiB total capacity; 1.77 GiB already allocated; 0 bytes free; 1.83 GiB reserved in total by PyTorch)
